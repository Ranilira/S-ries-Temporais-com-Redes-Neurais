# %% [markdown]
# N2 - Entrega Séries Temporais - Avaliação
# Alunos: Raniel Lira e Gabriel Oliveira
# Professor: RODRIGO OTAVIO RIBEIRO HAGSTROM
# Matéria: T1ESOFT08N | CIÊNCIA DE DADOS | 202611
#
#
# Realizar a programação em Linguagem Python ou R dos seguintes itens aplicados ao csv de dados para esta N2 (disponível nos materiais de aula):
#
# Obtenção de Tendẽncias: Mínimos Quadrados (1,0 pontos); Acurácio do modelo de Mínimos Quadrados (2,0); Estudo de Modelos - Linear, Quadrático, Logarítmico, Potenciação, e Exponencial - Comparativo como na Apostila (2,5 pontos); Obtenção de tendẽncias por médias móveis - pelo meno 2, sendo uma suavizada (1,5 pontos); regressão com Redes Neurais (3,0);
#
# Obs1:Imprimir resultados gráficos sempres que possível.
#
# Obs2: Grupo deve escolher apenas um produto, e definir no seu estudo os cortes temporais e os períodos, de maneira que seja possível perceber eventuais sazonalidades, e outros componentes da série.

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)


df = pd.read_csv('dados_N2.csv') # Carrega o arquivo CSV em um DataFrame

df.head() # Exibe as primeiras linhas do DataFrame para verificar os dados
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
df.tail() # Exibe as últimas linhas do DataFrame para verificar os dados
# Out:
#               date  store  item  sales
# 912995  2017-12-27     10    50     63
# 912996  2017-12-28     10    50     59
# 912997  2017-12-29     10    50     74
# 912998  2017-12-30     10    50     62
# 912999  2017-12-31     10    50     82

# %%
df.info() # Exibe informações sobre o DataFrame, como tipos de dados e contagem de valores não nulos
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    913000 non-null  str
#  1   store   913000 non-null  int64
#  2   item    913000 non-null  int64
#  3   sales   913000 non-null  int64
# dtypes: int64(3), str(1)
# memory usage: 27.9 MB

# %%
# Filtra o DataFrame para mostrar apenas as linhas onde item_id é igual a 1
df[df.item == 40].plot()
# Out:
# <Axes: >

# %%
# Converte a coluna 'date' para o tipo datetime
df.date = pd.to_datetime(df['date'])
df.info() # Verifica se a conversão foi bem-sucedida e o tipo de dados da coluna 'date' foi alterado para datetime
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   date    913000 non-null  datetime64[us]
#  1   store   913000 non-null  int64
#  2   item    913000 non-null  int64
#  3   sales   913000 non-null  int64
# dtypes: datetime64[us](1), int64(3)
# memory usage: 27.9 MB

# %%
df.set_index('date', inplace=True) # Define a coluna 'date' como índice do DataFrame
df.head() # Exibe as primeiras linhas do DataFrame para verificar a alteração do índice
# Out:
#             store  item  sales
# date
# 2013-01-01      1     1     13
# 2013-01-02      1     1     11
# 2013-01-03      1     1     14
# 2013-01-04      1     1     13
# 2013-01-05      1     1     10

# %%
df[df.item == 40].describe() # Exibe estatísticas descritivas do DataFrame, como média, desvio padrão, etc.
# Out:
#              store     item         sales
# count  18260.00000  18260.0  18260.000000
# mean       5.50000     40.0     29.249398
# std        2.87236      0.0     10.822959
# min        1.00000     40.0      3.000000
# 25%        3.00000     40.0     21.000000
# 50%        5.50000     40.0     28.000000
# 75%        8.00000     40.0     36.000000
# max       10.00000     40.0     74.000000

# %%
# Filtra o DataFrame para mostrar apenas as linhas onde item_id é igual a 40
df[df.item == 40].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df[df.item == 40].plot(figsize=(15,6)) # Plota o DataFrame completo para visualizar as tendências ao longo do tempo
# Out:
# <Axes: xlabel='date'>

# %%
sns.boxplot(x=df[df.item == 40]['item']) # Cria um boxplot para a coluna 'Item_40' para visualizar a distribuição dos dados e identificar possíveis outliers
# Out:
# <Axes: xlabel='item'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(df[df.item == 40]['store'], df[df.item == 40]['sales'])
ax.set_xlabel('sales')
ax.set_ylabel('store')
plt.show()

# %%
Quais informações temos sobre o passado??
O que podemos aprender com os dados históricos?
# Out:
# Object `passado` not found.
# Object `históricos` not found.
